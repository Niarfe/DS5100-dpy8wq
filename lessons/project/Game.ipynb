# %%
import sys
sys.path.append('/Users/praedator/Documents/UVA/MSDS/DS5100_project')

import unittest
import numpy as np
from app.die import Die
from app.game import Game
faces = np.array(['heads', 'tails'], dtype='object')
dice = [Die(faces), Die(faces)]
game = Game(dice)

game.play(5)
game.show(display='narrow')
# Out:
#          results
# roll die
# 0    0     tails
#      1     heads
# 1    0     tails
#      1     heads
# 2    0     heads
#      1     tails
# 3    0     heads
#      1     heads
# 4    0     heads
#      1     heads
